# %% [markdown]
# <a href="https://colab.research.google.com/github/Youssef-S-Ahmed/Credit-Card-Fraud-Detection/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data preprocessing Tools

# %% [markdown]
# # 1.Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#machine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # 2.importing Dataset.

# %%
dataset = pd.read_csv("creditcard.csv")
df = pd.DataFrame(dataset)
df
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0         0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1         0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2         1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3         1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4         2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 9960  14837  1.286884 -0.124610  0.148283 -0.259343  0.248357  0.896718
# 9961  14854  1.318742  0.496408  0.114876  0.695262  0.170133 -0.537180
# 9962  14857  1.241757  0.419587  0.806183  0.894811 -0.507886 -1.118126
# 9963  14861  1.304800 -0.052885  0.415235 -0.081725 -0.223525  0.097752
# 9964  14864 -1.747939  3.712444       NaN       NaN       NaN       NaN
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
combined_df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Count NaN values in each column
nan_counts = df.isna().sum()
nan_counts
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#dealing with rest col with Object dtype
df = df.dropna()

# %%
df.describe()
# Out:
#                Time           V1           V2           V3           V4  \
# count   9964.000000  9964.000000  9964.000000  9964.000000  9964.000000
# mean    5933.588719    -0.241530     0.280348     0.906359     0.260247
# std     4448.730907     1.522697     1.308496     1.156948     1.440500
# min        0.000000   -27.670569   -34.607649   -15.496222    -4.657545
# 25%     2061.000000    -1.011783    -0.208614     0.412198    -0.615591
# 50%     4546.000000    -0.372609     0.286168     0.943149     0.218492
# 75%    10162.250000     1.151550     0.900736     1.601871     1.119367
# max    14861.000000     1.960497     8.636214     4.101716    10.463020
#
#                 V5           V6           V7           V8           V9  ...  \
# count  9964.000000  9964.000000  9964.000000  9964.000000  9964.000000  ...
# mean     -0.046342     0.132335    -0.071847    -0.065317     0.801220  ...
# std       1.183634     1.307586     1.077872     1.260140     1.156424  ...
# ...

# %%
# Check the dataset shape
print(df.shape)
print(df['Class'].value_counts())
# Out:
# (9964, 31)
# Class
# 0.0    9926
# 1.0      38
# Name: count, dtype: int64

# %%
df['Class'].unique()
# Out:
# array([0., 1.])

# %%
df
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0         0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1         0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2         1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3         1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4         2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 9959  14834  1.180311 -0.268826  1.373170 -0.623739 -1.237326 -0.495057
# 9960  14837  1.286884 -0.124610  0.148283 -0.259343  0.248357  0.896718
# 9961  14854  1.318742  0.496408  0.114876  0.695262  0.170133 -0.537180
# 9962  14857  1.241757  0.419587  0.806183  0.894811 -0.507886 -1.118126
# 9963  14861  1.304800 -0.052885  0.415235 -0.081725 -0.223525  0.097752
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
x = df.iloc[: , :-1].values
y = df.iloc[: , -1].values

# %%
print (x) # x contains the features or the independent variables
print("--------------------------")
print(y) # y contains the dependent variables or the predicted that we want the model to be able to predict
# Out:
# [[ 0.00000000e+00 -1.35980713e+00 -7.27811733e-02 ...  1.33558377e-01
#   -2.10530535e-02  1.49620000e+02]
#  [ 0.00000000e+00  1.19185711e+00  2.66150712e-01 ... -8.98309914e-03
#    1.47241692e-02  2.69000000e+00]
#  [ 1.00000000e+00 -1.35835406e+00 -1.34016307e+00 ... -5.53527940e-02
#   -5.97518406e-02  3.78660000e+02]
#  ...
#  [ 1.48540000e+04  1.31874232e+00  4.96407864e-01 ... -4.61543712e-02
#    1.73042790e-02  1.78000000e+00]
#  [ 1.48570000e+04  1.24175672e+00  4.19586742e-01 ... -5.10838932e-02
#    1.72077499e-02  1.29000000e+00]
#  [ 1.48610000e+04  1.30480050e+00 -5.28847393e-02 ... -9.98514999e-02
#   -1.54037053e-02  4.72000000e+00]]
# --------------------------
# [0. 0. 0. ... 0. 0. 0.]

# %%
print(x.shape)
print(y.shape)
# Out:
# (9964, 30)
# (9964,)

# %% [markdown]
# # Splitting the Dataset into Training set & Test set

# %%
# creating instance
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size = 0.6 , random_state = 1)

print(x_train)
print("-----------------------")
print(y_train)
print("-----------------------")
print(x_test)
print("-----------------------")
print(y_test)
# Out:
# [[ 4.19200000e+03  1.06411656e+00 -1.02075105e+00 ... -4.80916357e-02
#    3.32391116e-02  1.25900000e+02]
#  [ 3.15700000e+03 -1.28371842e-01  9.57775425e-01 ...  2.33248522e-01
#    2.32709693e-01  1.84000000e+01]
#  [ 1.33230000e+04 -5.45436178e+00  8.28742056e+00 ...  1.57471478e+00
#    8.08725205e-01  1.00000000e+00]
#  ...
#  [ 6.81000000e+02  1.12087185e+00  1.42425238e-01 ...  5.75305839e-02
#    2.33089305e-02  9.99000000e+00]
#  [ 4.95600000e+03  1.30077372e+00  1.65218226e-01 ... -4.98938742e-02
#    1.84456980e-02  8.99000000e+00]
#  [ 1.56000000e+02 -3.49486086e+00 -2.89444973e+00 ...  3.09675191e-01
#    6.32260841e-01  5.00000000e+02]]
# -----------------------
# [0. 0. 1. ... 0. 0. 0.]
# -----------------------
# [[ 1.08390000e+04 -1.39716933e+00  1.27907156e+00 ...  2.47241015e-01
#    1.81637354e-01  2.50000000e+01]
#  [ 9.74400000e+03  1.19794207e+00  2.52099278e-03 ... -8.36097052e-02
#    4.65361642e-03  1.37100000e+01]
# ...

# %% [markdown]
# #SVM(Kernel'rbf')

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = "rbf" , random_state=0)
classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %%
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
from sklearn.metrics import confusion_matrix , accuracy_score
cm = confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred))
# Out:
# [[5963    0]
#  [  16    0]]
# 0.9973239672185984

# %% [markdown]
# #SVM(Kernel'Linear')

# %%
classifier_2 = SVC(kernel = "linear" , random_state=0)
classifier_2.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred_2 = classifier.predict(x_test)
print(y_pred_2)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
cm_2 = confusion_matrix(y_test,y_pred_2)
print(cm_2)
print(accuracy_score(y_test,y_pred_2))
# Out:
# [[5963    0]
#  [  16    0]]
# 0.9973239672185984

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier


c = RandomForestClassifier(n_estimators=10 , criterion="entropy", random_state=0)
c.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_p_3 = c.predict(x_train)

cmm = confusion_matrix(y_train,y_p_3)
print(cmm)
print(accuracy_score(y_train,y_p_3))
# Out:
# [[3963    0]
#  [   0   22]]
# 1.0

# %%
y_pred_3 = c.predict(x_test)

cm_3 = confusion_matrix(y_test,y_pred_3)
print(cm_3)
print(accuracy_score(y_test,y_pred_3))
# Out:
# [[5963    0]
#  [   2   14]]
# 0.9996654959023248
